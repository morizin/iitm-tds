# %%
import pandas as pd
import numpy as np
from PIL import Image

img = Image.open('download.png')
img_rgb = img.convert('RGB')

img_rgb.save('download_compressed.webp', "WEBP",lossless=True, quality=100)

# %%
from pathlib import Path
Path('download_compressed.webp').stat().st_size
# Out:
# 1262
